# %%
import joblib
import pandas as pd
import numpy as np

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

# %%
new_data = pd.read_csv('./Data/Cubic_unseen.csv')
new_data
# Out:
#      carat        cut color clarity  depth  table  Length_mm  Width_mm  \
# 0     0.40      Ideal     J     SI1   61.4   55.0       4.75      4.80
# 1     1.26      Ideal     D     VS2   62.5   57.0       6.90      6.85
# 2     2.23    Premium     J     SI2   61.3   60.0       8.40      8.35
# 3     1.33    Premium     E     SI2   62.5   58.0       6.99      7.03
# 4     0.42      Ideal     G     VS2   62.2   54.1       4.80      4.83
# ..     ...        ...   ...     ...    ...    ...        ...       ...
# 195   0.33    Premium     G     VS2   60.8   58.0       4.45      4.47
# 196   1.18  Very Good     H     SI1   62.6   55.0       6.76      6.79
# 197   0.30  Very Good     E     SI2   61.6   61.0       4.25      4.29
# 198   0.51      Ideal     D     VS2   61.2   55.0       5.13      5.17
# 199   0.46  Very Good     F     SI2   62.6   58.0       4.88      4.96
#
#      Height_mm  price
# 0         2.93    612
# 1         4.30   8256
# 2         5.13  13931
# ...

# %%
model = joblib.load('./CubicModel.pkl')
print(model)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['carat', 'depth', 'table',
#                                                    'Length_mm', 'Width_mm',
#                                                    'Height_mm']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(fill_value='N/A',
# ...

# %%
pred = model.predict(new_data)
pred
new_data['pred']= pd.DataFrame(pred)
new_data
# Out:
#      carat        cut color clarity  depth  table  Length_mm  Width_mm  \
# 0     0.40      Ideal     J     SI1   61.4   55.0       4.75      4.80
# 1     1.26      Ideal     D     VS2   62.5   57.0       6.90      6.85
# 2     2.23    Premium     J     SI2   61.3   60.0       8.40      8.35
# 3     1.33    Premium     E     SI2   62.5   58.0       6.99      7.03
# 4     0.42      Ideal     G     VS2   62.2   54.1       4.80      4.83
# ..     ...        ...   ...     ...    ...    ...        ...       ...
# 195   0.33    Premium     G     VS2   60.8   58.0       4.45      4.47
# 196   1.18  Very Good     H     SI1   62.6   55.0       6.76      6.79
# 197   0.30  Very Good     E     SI2   61.6   61.0       4.25      4.29
# 198   0.51      Ideal     D     VS2   61.2   55.0       5.13      5.17
# 199   0.46  Very Good     F     SI2   62.6   58.0       4.88      4.96
#
#      Height_mm  price          pred
# 0         2.93    612    572.335286
# 1         4.30   8256   9736.259464
# ...

# %%
r2 = r2_score(new_data.price, pred)
mae = mean_absolute_error(new_data.price, pred)
mean_act = new_data.price.mean()
mean_pred = pred.mean()
min_act = min(new_data.price)
max_act = max(new_data.price)
mape = mean_absolute_percentage_error(new_data.price, pred)
print(f'R2: {r2}\nmae: {mae}\nact_mean: {mean_act}\npred_mean: {mean_pred}\nmape: {mape}\nact_range: {min_act} to {max_act}')
# Out:
# R2: 0.9866332255331216
# mae: 289.7419908670857
# act_mean: 4103.195
# pred_mean: 4083.3615268921294
# mape: 0.08071865204883168
# act_range: 402 to 18572
